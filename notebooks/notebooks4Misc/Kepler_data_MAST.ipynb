# %% [markdown]
# # MAST - Kepler data archive
# * 原作者: 張瀚元; 修編者: 蘇羿豪
# * [Mikulski Archive for Space Telescopes (MAST)](https://archive.stsci.edu)

# %%
from IPython.display import display, Image
for i in range(16):
    print('Slide ' + str(i+1) + ': ')
    display(Image('./images/kepler_p' + str(i+1) + '.png', width=800))
# Out:
# Slide 1:
# Slide 2:
# Slide 3:
# Slide 4:
# Slide 5:
# Slide 6:
# Slide 7:
# Slide 8:
# Slide 9:
# Slide 10:
# Slide 11:
# Slide 12:
# Slide 13:
# Slide 14:
# Slide 15:
# Slide 16:

# %% [markdown]
# ## 爬蟲 (尚未完成)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get("https://archive.stsci.edu/kepler/data_search/search.php")
#driver.get("https://archive.stsci.edu/kepler/kepler_fov/search.php")

target = "9726699"
target_input = driver.find_element_by_name("target") 
target_input.clear()
target_input.send_keys(target)
target_input.send_keys(Keys.RETURN)
